# %%
import random,time,copy
turns=random.randint(0,1)
choice=0
#turns=1
noofmoves=0
y=0
theboard={'top1':' ','top2':' ','top3':' ',
          'mid1':' ','mid2':' ','mid3':' ',
          'bot1':' ','bot2':' ','bot3':' '
         }
def printboard(board):
    x=0
    print('-+-+-+-')
    print('|'+board['top1']+'|'+board['top2']+'|'+board['top3']+'|')
    print('-+-+-+-')
    print('|'+board['mid1']+'|'+board['mid2']+'|'+board['mid3']+'|')
    print('-+-+-+-')
    print('|'+board['bot1']+'|'+board['bot2']+'|'+board['bot3']+'|')
    print('-+-+-+-')
    if ((board['top1']==board['top2']==board['top3']=='X') or (board['mid1']==board['mid2']==board['mid3']=='X')
        or (board['bot1']==board['bot2']==board['bot3']=='X') or (board['top1']==board['mid2']==board['bot3']=='X')
        or (board['top3']==board['mid2']==board['bot1']=='X') or (board['top1']==board['mid1']==board['bot1']=='X') 
        or (board['top2']==board['mid2']==board['bot2']=='X')  or (board['top3']==board['mid3']==board['bot3'])=='X'):
       x=1  
    elif ((board['top1']==board['top2']==board['top3']=='O') or (board['mid1']==board['mid2']==board['mid3']=='O')
        or (board['bot1']==board['bot2']==board['bot3']=='O') or (board['top1']==board['mid2']==board['bot3']=='O')
        or (board['top3']==board['mid2']==board['bot1']=='O') or (board['top1']==board['mid1']==board['bot1']=='O') 
        or (board['top2']==board['mid2']==board['bot2']=='O')  or (board['top3']==board['mid3']==board['bot3'])=='O'):
       x=2  
    
    elif (board['top1']!=' ' and board['top2']!=' ' and board['top3']!=' ' and board['mid1']!=' ' and
        board['mid2'] and board['mid3'] !=' ' and board['bot1']!=' ' and board['bot2']!=' ' and board['bot3']!=' '):
        x=3
    else:
        x=0
    return x

    

def computermove(board):

########### CHECKING FOR TWO CELLS ='O'
 #######check for two of 3 cells filed (two of  T1,T2,T3 for ='O')
    if (board['top1']== 'O' and board['top3']=='O' and theboard['top2']==' '):
        theboard['top2']='O'
        usednumbers[1]=2
    elif (board['top1']== 'O' and board['top2']=='O' and theboard['top3']==' '):
        theboard['top3']='O'
        usednumbers[2]=3
    elif (board['top3']== 'O' and board['top2']=='O' and theboard['top1']==' '):
        theboard['top1']='O'
        usednumbers[0]=1
#####  (two of  M1,M2,M3 for ='O')   
    elif (board['mid1']== 'O' and board['mid3']=='O' and theboard['mid2']==' '):
        theboard['mid2']='O'
        usednumbers[4]=5
    elif (board['mid1']== 'O' and board['mid2']=='O' and theboard['mid3']==' '):
         theboard['mid3']='O'
         usednumbers[5]=6   
    elif (board['mid3']== 'O' and board['mid2']=='O' and theboard['mid1']==' '):
        theboard['mid1']='O'
        usednumbers[3]=4
     ####(two of  B1,B2,B3 for ='O')  
    elif (board['bot1']== 'O' and board['bot3']=='O' and theboard['bot2']==' '):
        theboard['bot2']='O'
        usednumbers[7]=8
    elif (board['bot1']== 'O' and board['bot2']=='O' and theboard['bot3']==' '):
        theboard['bot3']='O'
        usednumbers[8]=9
    elif (board['bot3']== 'O' and board['bot2']=='O' and theboard['bot1']==' '):
        theboard['bot1']='O'
        usednumbers[6]=7
        
#####  (two of  T1,M1,B1 for ='O')      
    elif (board['top1']== 'O' and board['bot1']=='O' and theboard['mid1']==' '):
        theboard['mid1']='O'
        usednumbers[4]=5
    elif (board['top1']== 'O' and board['mid1']=='O' and theboard['bot1']==' '):
        theboard['bot1']='O'
        usednumbers[6]=7
    elif (board['mid1']=='O' and board['bot1']=='O'  and theboard['top1']==' '):
        theboard['top1']='O'
        usednumbers[0]=1
#####  (two of  T2,M2,B2 for ='O')    
    elif (board['top2']== 'O' and board['bot2']=='O' and theboard['mid2']==' '):
        theboard['mid2']='O'
        usednumbers[4]=5
    elif (board['top2']== 'O' and board['mid2']=='O' and theboard['bot2']==' '):
        theboard['bot2']='O'
        usednumbers[7]=8
    elif (board['mid2']== 'O' and board['bot2']=='O' and theboard['top2']==' '):
        theboard['top2']='O'
        usednumbers[1]=2
#####  (two of  T3,M3,B3 for ='O')      
    elif (board['top3']== 'O' and board['bot3']=='O' and theboard['mid3']==' '):
        theboard['mid3']='O'
        usednumbers[5]=6
    elif (board['top3']== 'O' and board['mid3']=='O' and theboard['bot3']==' '):
        theboard['bot3']='O'
        usednumbers[8]=9
    elif (board['mid3']== 'O' and board['bot3']=='O' and theboard['top3']==' '):
        theboard['top3']='O'
        usednumbers[2]=3
 #####  (two of  T1,M2,B3 for ='O')     
    elif (board['top1']== 'X' and board['bot3']=='O' and theboard['mid2']==' '):
        theboard['mid2']='O'
        usednumbers[4]=5
    elif (board['top1']== 'O' and board['mid2']=='O' and theboard['bot3']==' '):
        theboard['bot3']='O'
        usednumbers[8]=9
    elif (board['mid2']== 'O' and board['bot3']=='O' and theboard['top1']==' '):
        theboard['top1']='O'
        usednumbers[0]=1
#####  (two of  T3,M2,B1 for ='O')     
    elif (board['top3']== 'O' and board['bot1']=='O' and theboard['mid2']==' '):
        theboard['mid2']='O'
        usednumbers[4]=5
    elif (board['top3']== 'O' and board['mid2']=='O' and theboard['bot1']==' '):
        theboard['bot1']='O'
        usednumbers[6]=7
    elif (board['mid2']== 'O' and board['bot1']=='O' and theboard['top3']==' '):
        theboard['top3']='O'
        usednumbers[2]=3
             
    
#######check for two of 3 cells filed (two of  T1,T2,T3 for ='X')
#####  (two of  T1,T2,T3 for ='X') 
    elif (board['top1']== 'X' and board['top3']=='X' and theboard['top2']==' '):
        theboard['top2']='O'
        usednumbers[1]=2
    elif (board['top1']== 'X' and board['top2']=='X' and theboard['top3']==' '):
        theboard['top3']='O'
        usednumbers[2]=3
    elif (board['top3']== 'X' and board['top2']=='X' and theboard['top1']==' '):
        theboard['top1']='O'
        usednumbers[0]=1
#####  (two of  M1,M2,M3 for ='X')   
    elif (board['mid1']== 'X' and board['mid3']=='X' and theboard['mid2']==' '):
        theboard['mid2']='O'
        usednumbers[4]=5
    elif (board['mid1']== 'X' and board['mid2']=='X' and theboard['mid3']==' '):
         theboard['mid3']='O'
         usednumbers[5]=6   
    elif (board['mid3']== 'X' and board['mid2']=='X' and theboard['mid1']==' '):
        theboard['mid1']='O'
        usednumbers[3]=4
 ####(two of  B1,B2,B3 for ='X')  
    elif (board['bot1']== 'X' and board['bot3']=='X' and theboard['bot2']==' '):
        theboard['bot2']='O'
        usednumbers[7]=8
    elif (board['bot1']== 'X' and board['bot2']=='X' and theboard['bot3']==' '):
        theboard['bot3']='O'
        usednumbers[8]=9
    elif (board['bot3']== 'X' and board['bot2']=='X' and theboard['bot1']==' '):
        theboard['bot1']='O'
        usednumbers[6]=7
        
#####  (two of  T1,M1,B1 for ='O')      
    elif (board['top1']== 'X' and board['bot1']=='X' and theboard['mid1']==' '):
        theboard['mid1']='O'
        usednumbers[3]=4
    elif (board['top1']== 'X' and board['mid1']=='X' and theboard['bot1']==' '):
        theboard['bot1']='O'
        usednumbers[6]=7
    elif (board['mid1']=='X' and board['bot1']=='X'  and theboard['top1']==' '):
        theboard['top1']='O'
        usednumbers[0]=1
#####  (two of  T2,M2,B2 for ='O')    
    elif (board['top2']== 'X' and board['bot2']=='X' and theboard['mid2']==' '):
        theboard['mid2']='O'
        usednumbers[4]=5
    elif (board['top2']== 'X' and board['mid2']=='X' and theboard['bot2']==' '):
        theboard['bot2']='O'
        usednumbers[7]=8
    elif (board['mid2']== 'X' and board['bot2']=='X' and theboard['top2']==' '):
        theboard['top2']='O'
        usednumbers[1]=2
#####  (two of  T3,M3,B3 for ='O')      
    elif (board['top3']== 'X' and board['bot3']=='X' and theboard['mid3']==' '):
        theboard['mid3']='O'
        usednumbers[5]=6
    elif (board['top3']== 'X' and board['mid3']=='X' and theboard['bot3']==' '):
        theboard['bot3']='O'
        usednumbers[8]=9
    elif (board['mid3']== 'X' and board['bot3']=='X' and theboard['top3']==' '):
        theboard['top3']='O'
        usednumbers[2]=3
 #####  (two of  T1,M2,B3 for ='O')     
    elif (board['top1']== 'X' and board['bot3']=='X' and theboard['mid2']==' '):
        theboard['mid2']='O'
        usednumbers[4]=5
    elif (board['top1']== 'X' and board['mid2']=='X' and theboard['bot3']==' '):
        theboard['bot3']='O'
        usednumbers[8]=9
    elif (board['mid2']== 'X' and board['bot3']=='X' and theboard['top1']==' '):
        theboard['top1']='O'
        usednumbers[0]=1
#####  (two of  T3,M2,B1 for ='O')     
    elif (board['top3']== 'X' and board['bot1']=='X' and theboard['mid2']==' '):
        theboard['mid2']='O'
        usednumbers[4]=5
    elif (board['top3']== 'X' and board['mid2']=='X' and theboard['bot1']==' '):
        theboard['bot1']='O'
        usednumbers[6]=7
    elif (board['mid2']== 'X' and board['bot1']=='X' and theboard['top3']==' '):
        theboard['top3']='O'
        usednumbers[0]=1
              
#############  CHECKING SINGLE CELLS
    elif (board['mid2']== ' '):
         theboard['mid2']='O'
         usednumbers[4]=5   
    elif (board['top1']== ' '):
          theboard['top1']='O'
          usednumbers[0]=1  
    elif (board['top2']== ' '):
          theboard['top2']='O'
          usednumbers[1]=2
    elif (board['top3']== ' '):
          theboard['top3']='O'
          usednumbers[2]=3  
    elif (board['bot1']== ' '):
          theboard['bot1']='O'
          usednumbers[6]=7
    elif (board['bot2']== ' '):
          theboard['bot2']='O'
          usednumbers[7]=8
    elif (board['bot3']== ' '):
          theboard['bot3']='O'
          usednumbers[8]=9
    elif (board['mid3']== ' '):
         theboard['mid3']='O'
         usednumbers[5]=6
    elif (board['mid1']== ' '):
         theboard['mid1']='O'
         usednumbers[3]=4
################                
#printboard(theboard)
usednumbers=[0,0,0,0,0,0,0,0,0]
if turns==0:
    turn="O"
    theboard['mid2']='O'
    usednumbers[4]=5
    print(' COMPUTER PLAYED FIRST NOW YOUR TURN')
    printboard(theboard)
    choice=0
    noofmoves=noofmoves+1
else:
#    theboard['mid2']='X'
#    printboard(theboard)
#    computermove(theboard)
    printboard(theboard)
    choice=0
    noofmoves=noofmoves+1

x=0
gameover=False
choice=0
while gameover== False:
        
    print('your turn to select space?')
    print('select 1 for top left.. 2 for top-middle  3 for top right')
    print('select 4 for mid left.. 5 for mid-middle  6 for mid right')
    print('select 7 for bottom left.. 8 for bottom-middle  9 for bottom right')
    print('except ')
    for i in range (9):
        if usednumbers[i]>0:
            print(i+1 , end=' ')
    choice=int(input())
    if choice<0 or choice>9 or usednumbers[choice-1]!=0:
        print ('improper choice .. enter correct choice')
        continue
    
    elif choice>0 and choice<4:
        usednumbers[choice-1]=choice
        move='top'+str(choice)
        theboard[move]='X'
        y=printboard(theboard)
        print('Y ='+str(y))
        if y>0:
           break 
        computermove(theboard)
        y=printboard(theboard)
        print('Y ='+str(y))
        if y>0:
           break 
        choice=0
    elif choice>3 and choice<7:
        usednumbers[choice-1]=choice
        move='mid'+str(choice-3)
        theboard[move]='X'
        y=printboard(theboard)
        print('Y ='+str(y))
        if y>0:
           break 
        computermove(theboard)
        y=printboard(theboard)
        print('Y ='+str(y))
        if y>0:
           break 
        choice=0
    elif choice>6 and choice<10:
        usednumbers[choice-1]=choice
        move='bot'+str(choice-6)
        theboard[move]='X'
        y=printboard(theboard)
        print('Y ='+str(y))
        if y>0:
           break 
        computermove(theboard)
        y=printboard(theboard)
        print('Y ='+str(y))
        if y>0:
           break 
        choice=0
       
    
    noofmoves=noofmoves+1
    #printboard(theboard)  
    #computermove(theboard)
                 
if y==3:
    print('GAME IS TIED')
if y==1:
    print('YOU HAVE WON')
if y==2:
    print('COMPUTER HAS WON')


#printboard(theboard)
